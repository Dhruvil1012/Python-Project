# %% [markdown]
# # Loading all the libraries and modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import EDA.dsa_info as info
import EDA.dsa_load_data as load_data
import EDA.plot_data as plot
import EDA.Dsa_scatter as dsa_scatter
import EDA.dsa_maths as maths

# %% [markdown]
# # 1. Loading the datatset

# %%
netflix_data = load_data.load_data('/Users/dhruvilshah/Downloads/netflix_titles.csv')
netflix_data2 = load_data.load_data(('/Users/dhruvilshah/Downloads/netflix1.csv'))

# %%
netflix_info = info.info_data(netflix_data)

# %% [markdown]
# # Merging the dataset

# %%
netflix_data = netflix_info.merge_dataframe(netflix_data2,"country")

# %% [markdown]
# # Information of data and also initializing info and plot modules for further process

# %%
netflix_plot = plot.Plot(netflix_info.get_df())

# %% [markdown]
# # Datatypes and describe module

# %%
netflix_info.datatypes_time()

# %%
netflix_info.describe_data()
# Out:
#   show_id_x type_x               title_x       director_x cast        country  \
# 0        s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
# 1        s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
# 2        s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
# 3        s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
# 4        s1  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#   date_added_x  release_year_x rating_x duration_x  ...  \
# 0   2021-09-25            2020    PG-13     90 min  ...
# 1   2021-09-25            2020    PG-13     90 min  ...
# 2   2021-09-25            2020    PG-13     90 min  ...
# 3   2021-09-25            2020    PG-13     90 min  ...
# 4   2021-09-25            2020    PG-13     90 min  ...
#
#                         director_y date_added_y release_year_y rating_y  \
# 0                  Kirsten Johnson   2021-09-25           2020    PG-13
# ...

# %%
netflix_info.datatypes()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10764817 entries, 0 to 10764816
# Data columns (total 25 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   show_id_x       object
#  1   type_x          object
#  2   title_x         object
#  3   director_x      object
#  4   cast            object
#  5   country         object
#  6   date_added_x    datetime64[ns]
#  7   release_year_x  int64
#  8   rating_x        object
#  9   duration_x      object
#  10  listed_in_x     object
#  11  description     object
#  12  show_id_y       object
#  13  type_y          object
#  14  title_y         object
#  15  director_y      object
#  16  date_added_y    datetime64[ns]
#  17  release_year_y  int64
#  18  rating_y        object
#  19  duration_y      object
#  20  listed_in_y     object
#  21  year_added_y    int64
#  22  month_added_y   int64
#  23  year_added_x    float64
#  24  month_added_x   float64
# ...

# %% [markdown]
# # Null values and duplicate value

# %%
netflix_info.nulls()
# Out:
# show_id_x               0
# type_x                  0
# title_x                 0
# director_x        2858298
# cast              1165891
# country                 0
# date_added_x        20451
# release_year_x          0
# rating_x              439
# duration_x           9720
# listed_in_x             0
# description             0
# show_id_y               0
# type_y                  0
# title_y                 0
# director_y              0
# date_added_y            0
# release_year_y          0
# rating_y                0
# duration_y              0
# listed_in_y             0
# year_added_y            0
# month_added_y           0
# year_added_x        20451
# month_added_x       20451
# dtype: int64
# show_id_x         10764817
# type_x            10764817
# title_x           10764817
# director_x         7906519
# cast               9598926
# country           10764817
# date_added_x      10744366
# release_year_x    10764817
# rating_x          10764378
# ...

# %%
netflix_info.duplicate()
# Out:
# 0

# %% [markdown]
# # Null value heatmap

# %%
netflix_plot.null_heatmap()

# %% [markdown]
# # Missing values and unwanted column and matrix form

# %%
netflix_info.show_missing("release_year_x","date_added_x","year_added_x")
# Out:
# Empty DataFrame
# Columns: [show_id_x, type_x, title_x, director_x, cast, country, date_added_x, release_year_x, rating_x, duration_x, listed_in_x, description, show_id_y, type_y, title_y, director_y, date_added_y, release_year_y, rating_y, duration_y, listed_in_y, year_added_y, month_added_y, year_added_x, month_added_x]
# Index: []
#
# [0 rows x 25 columns]
#          show_id_x   type_x                          title_x director_x  \
# 6023160      s6175  TV Show  Anthony Bourdain: Parts Unknown        NaN
# 6023161      s6175  TV Show  Anthony Bourdain: Parts Unknown        NaN
# 6023162      s6175  TV Show  Anthony Bourdain: Parts Unknown        NaN
# 6023163      s6175  TV Show  Anthony Bourdain: Parts Unknown        NaN
# 6023164      s6175  TV Show  Anthony Bourdain: Parts Unknown        NaN
# ...            ...      ...                              ...        ...
# 10532969     s6902  TV Show                  Gunslinger Girl        NaN
# ...

# %%
netflix_info.unwantedcolumn('show_id_x','cast','director_x')
# Out:
#            type_x                            title_x       director_x  \
# 0           Movie               Dick Johnson Is Dead  Kirsten Johnson
# 1           Movie               Dick Johnson Is Dead  Kirsten Johnson
# 2           Movie               Dick Johnson Is Dead  Kirsten Johnson
# 3           Movie               Dick Johnson Is Dead  Kirsten Johnson
# 4           Movie               Dick Johnson Is Dead  Kirsten Johnson
# ...           ...                                ...              ...
# 10764812    Movie  Septiembre, un llanto en silencio   Kenneth Müller
# 10764813  TV Show              Servant of the People              NaN
# 10764814  TV Show              Servant of the People              NaN
# 10764815  TV Show                        The Sniffer              NaN
# 10764816  TV Show                        The Sniffer              NaN
#
#                                                        cast        country  \
# ...

# %%
netflix_info.matrix_form()
# Out:
# [  type_x               title_x        country date_added_x  release_year_x  \
#  1  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
#
#    rating_x duration_x    listed_in_x  \
#  1    PG-13     90 min  Documentaries
#
#                                           description show_id_y  ...  \
#  1  As her father nears the end of his life, filmm...        s6  ...
#
#        director_y date_added_y release_year_y rating_y  duration_y  \
#  1  Mike Flanagan   2021-09-24           2021    TV-MA    1 Season
#
#                            listed_in_y year_added_y month_added_y  \
#  1  TV Dramas, TV Horror, TV Mysteries         2021             9
#
#     year_added_x  month_added_x
#  1        2021.0            9.0
#
#  [1 rows x 22 columns]
#    type_x               title_x        country date_added_x  release_year_x  \
#  1  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
# ...

# %%
netflix_info.get_df().rename(columns = {'listed_in' : 'Genre',}, inplace = True)

# %% [markdown]
# # Removing null values and plotting heatmap

# %%
netflix_info.removenull()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10734207 entries, 0 to 10764816
# Data columns (total 22 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   type_x          object
#  1   title_x         object
#  2   country         object
#  3   date_added_x    datetime64[ns]
#  4   release_year_x  int64
#  5   rating_x        object
#  6   duration_x      object
#  7   listed_in_x     object
#  8   description     object
#  9   show_id_y       object
#  10  type_y          object
#  11  title_y         object
#  12  director_y      object
#  13  date_added_y    datetime64[ns]
#  14  release_year_y  int64
#  15  rating_y        object
#  16  duration_y      object
#  17  listed_in_y     object
#  18  year_added_y    int64
#  19  month_added_y   int64
#  20  year_added_x    float64
#  21  month_added_x   float64
# dtypes: datetime64[ns](2), float64(2), int64(4), object(14)
# memory usage: 1.8+ GB
# None

# %%
netflix_info.get_df()
# Out:
#            type_x                            title_x        country  \
# 0           Movie               Dick Johnson Is Dead  United States
# 1           Movie               Dick Johnson Is Dead  United States
# 2           Movie               Dick Johnson Is Dead  United States
# 3           Movie               Dick Johnson Is Dead  United States
# 4           Movie               Dick Johnson Is Dead  United States
# ...           ...                                ...            ...
# 10764812    Movie  Septiembre, un llanto en silencio      Guatemala
# 10764813  TV Show              Servant of the People        Ukraine
# 10764814  TV Show              Servant of the People        Ukraine
# 10764815  TV Show                        The Sniffer        Ukraine
# 10764816  TV Show                        The Sniffer        Ukraine
#
#          date_added_x  release_year_x rating_x duration_x  \
# 0          2021-09-25            2020    PG-13     90 min
# ...

# %%
netflix_plot.get_heatmap()

# %% [markdown]
# # Pair Plot

# %%
netflix_plot.get_pair_plot()

# %% [markdown]
# # Pie Chart

# %%
netflix_plot.pie_chart_type('type_x')
# Out:
# Movie      7929585
# TV Show    2835232
# Name: type_x, dtype: int64

# %%
netflix_plot.pie_chart_type('type_y')
# Out:
# Movie      8052788
# TV Show    2712029
# Name: type_y, dtype: int64

# %%
netflix_plot.pie_chart_column('country')

# %% [markdown]
# # Initializing the maths module

# %%
netflix_maths = maths.maths_dsa(netflix_info.get_df())

# %% [markdown]
# # Plotting the distribution of country and type which include tv and movie

# %%
netflix_plot.distribution_type('country','type_x')
# Out:
# United States     9130320
# India             1027404
# United Kingdom     267322
# Japan               63455
# Canada              49051
# Name: country, dtype: int64

# %%
netflix_plot.distribution_type('country','type_y')
# Out:
# United States     9130320
# India             1027404
# United Kingdom     267322
# Japan               63455
# Canada              49051
# Name: country, dtype: int64

# %%
netflix_plot.distribution_rating_type('rating_x','type_x')
# Out:
# TV-MA    3539035
# TV-14    2044025
# R        1455378
# TV-PG    1036755
# PG-13     948100
# Name: rating_x, dtype: int64

# %%
netflix_plot.distribution_rating_type('rating_y','type_y')
# Out:
# TV-MA    3323765
# TV-14    1942396
# R        1571472
# PG-13    1063109
# TV-PG     970821
# Name: rating_y, dtype: int64

# %% [markdown]
# # Analyzing the data

# %%
netflix_maths.slicing_data('release_year_x','2016')
# Out:
#   type_x               title_x        country date_added_x  release_year_x  \
# 0  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
# 1  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
# 2  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
# 3  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
# 4  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
#
#   rating_x duration_x    listed_in_x  \
# 0    PG-13     90 min  Documentaries
# 1    PG-13     90 min  Documentaries
# 2    PG-13     90 min  Documentaries
# 3    PG-13     90 min  Documentaries
# 4    PG-13     90 min  Documentaries
#
#                                          description show_id_y  ...  \
# 0  As her father nears the end of his life, filmm...        s1  ...
# 1  As her father nears the end of his life, filmm...        s6  ...
# 2  As her father nears the end of his life, filmm...        s8  ...
# ...

# %%
netflix_maths.slicing_data('release_year_y','2016')
# Out:
#   type_x               title_x        country date_added_x  release_year_x  \
# 0  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
# 1  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
# 3  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
# 4  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
# 5  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
#
#   rating_x duration_x    listed_in_x  \
# 0    PG-13     90 min  Documentaries
# 1    PG-13     90 min  Documentaries
# 3    PG-13     90 min  Documentaries
# 4    PG-13     90 min  Documentaries
# 5    PG-13     90 min  Documentaries
#
#                                          description show_id_y  ...  \
# 0  As her father nears the end of his life, filmm...        s1  ...
# 1  As her father nears the end of his life, filmm...        s6  ...
# 3  As her father nears the end of his life, filmm...       s10  ...
# ...

# %%
netflix_maths.category('2016','release_year_x')
# Out:
#       type_x                        title_x        country date_added_x  \
# 97200  Movie  Janoskians: Untold and Untrue  United States   2021-09-01
# 97201  Movie  Janoskians: Untold and Untrue  United States   2021-09-01
# 97202  Movie  Janoskians: Untold and Untrue  United States   2021-09-01
# 97203  Movie  Janoskians: Untold and Untrue  United States   2021-09-01
# 97204  Movie  Janoskians: Untold and Untrue  United States   2021-09-01
#
#        release_year_x rating_x duration_x listed_in_x  \
# 97200            2016    TV-MA     88 min    Comedies
# 97201            2016    TV-MA     88 min    Comedies
# 97202            2016    TV-MA     88 min    Comedies
# 97203            2016    TV-MA     88 min    Comedies
# 97204            2016    TV-MA     88 min    Comedies
#
#                                              description show_id_y  ...  \
# 97200  Follow the story of three Australian brothers ...        s1  ...
# ...

# %%
netflix_maths.category('2016','release_year_y')
# Out:
#     type_x               title_x        country date_added_x  release_year_x  \
# 33   Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
# 107  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
# 149  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
# 182  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
# 230  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
#
#     rating_x duration_x    listed_in_x  \
# 33     PG-13     90 min  Documentaries
# 107    PG-13     90 min  Documentaries
# 149    PG-13     90 min  Documentaries
# 182    PG-13     90 min  Documentaries
# 230    PG-13     90 min  Documentaries
#
#                                            description show_id_y  ...  \
# 33   As her father nears the end of his life, filmm...      s153  ...
# 107  As her father nears the end of his life, filmm...      s353  ...
# ...

# %%
netflix_maths.slice_data(1,2)
# Out:
#   type_x               title_x        country date_added_x  release_year_x  \
# 1  Movie  Dick Johnson Is Dead  United States   2021-09-25            2020
#
#   rating_x duration_x    listed_in_x  \
# 1    PG-13     90 min  Documentaries
#
#                                          description show_id_y  ...  \
# 1  As her father nears the end of his life, filmm...        s6  ...
#
#       director_y date_added_y release_year_y rating_y  duration_y  \
# 1  Mike Flanagan   2021-09-24           2021    TV-MA    1 Season
#
#                           listed_in_y year_added_y month_added_y  \
# 1  TV Dramas, TV Horror, TV Mysteries         2021             9
#
#    year_added_x  month_added_x
# 1        2021.0            9.0
#
# [1 rows x 22 columns]

# %%
netflix_maths.slice_by_year('release_year_x',2016)
# Out:
#          type_x                        title_x        country date_added_x  \
# 97200     Movie  Janoskians: Untold and Untrue  United States   2021-09-01
# 97201     Movie  Janoskians: Untold and Untrue  United States   2021-09-01
# 97202     Movie  Janoskians: Untold and Untrue  United States   2021-09-01
# 97203     Movie  Janoskians: Untold and Untrue  United States   2021-09-01
# 97204     Movie  Janoskians: Untold and Untrue  United States   2021-09-01
# ...         ...                            ...            ...          ...
# 10762243  Movie                         Janaan       Pakistan   2017-09-15
# 10762244  Movie                         Janaan       Pakistan   2017-09-15
# 10762245  Movie                         Janaan       Pakistan   2017-09-15
# 10762246  Movie                         Janaan       Pakistan   2017-09-15
# 10762247  Movie                         Janaan       Pakistan   2017-09-15
#
#           release_year_x rating_x duration_x  \
# ...

# %%
netflix_maths.slice_by_year('release_year_y',2016)
# Out:
#          type_x                         title_x        country date_added_x  \
# 33        Movie            Dick Johnson Is Dead  United States   2021-09-25
# 107       Movie            Dick Johnson Is Dead  United States   2021-09-25
# 149       Movie            Dick Johnson Is Dead  United States   2021-09-25
# 182       Movie            Dick Johnson Is Dead  United States   2021-09-25
# 230       Movie            Dick Johnson Is Dead  United States   2021-09-25
# ...         ...                             ...            ...          ...
# 10764781  Movie       How to Get Over a Breakup           Peru   2018-10-20
# 10764787  Movie  Pacificum: Return to the Ocean           Peru   2018-06-15
# 10764793  Movie                      Asu Mare 2           Peru   2016-12-01
# 10764799  Movie                 Sinister Circle           Peru   2019-10-01
# 10764802  Movie      Day of the Dead: Bloodline       Bulgaria   2018-04-05
#
#           release_year_x rating_x duration_x  \
# ...

# %%
netflix_maths.calculate_mean('release_year_x')
# Out:
# 2013.3108015338255

# %%
netflix_maths.calculate_median('release_year_y')
# Out:
# 2017.0

# %%
import EDA.Dsa_scatter as dsa_scatter
netflix_scatter = dsa_scatter.ScatterPlot(netflix_info.get_df())

# %%
netflix_maths.calculate_mode('release_year_x')
# Out:
# 2018

# %% [markdown]
# # Scatter plot between date added and release year which shows when it is released and date added on netflix

# %%
netflix_scatter.create_plot('date_added_x','release_year_x')

# %% [markdown]
# # Histogram showing outliers of particular or specified column and also on that year how many movies was released

# %%
netflix_plot.get_outliers_histogram('release_year_x')

# %% [markdown]
# # Box plot showing outliers of particular or specified column and also on that year how many movies was released

# %%
sns.boxplot(x=netflix_data['release_year_x'])
# Out:
# <AxesSubplot:xlabel='release_year_x'>

# %% [markdown]
# # Pair plot showing relation

# %%
netflix_plot.get_pair_plot()

# %% [markdown]
# # Histogram plot of netflix data

# %%
netflix_plot.plot_hist()

# %%
netflix_info.get_df()
# Out:
#            type_x                            title_x        country  \
# 0           Movie               Dick Johnson Is Dead  United States
# 1           Movie               Dick Johnson Is Dead  United States
# 2           Movie               Dick Johnson Is Dead  United States
# 3           Movie               Dick Johnson Is Dead  United States
# 4           Movie               Dick Johnson Is Dead  United States
# ...           ...                                ...            ...
# 10764812    Movie  Septiembre, un llanto en silencio      Guatemala
# 10764813  TV Show              Servant of the People        Ukraine
# 10764814  TV Show              Servant of the People        Ukraine
# 10764815  TV Show                        The Sniffer        Ukraine
# 10764816  TV Show                        The Sniffer        Ukraine
#
#          date_added_x  release_year_x rating_x duration_x  \
# 0          2021-09-25            2020    PG-13     90 min
# ...

# %% [markdown]
# # Taking different format like I have taken json format and converted to dataframe and worked on some mathematical and statistical calculation and also used count function

# %%
import json
import pandas as pd

# %%
netflix_movies = json.load(open('/Users/dhruvilshah/Downloads/Python project/EDA/movies.json','r'))

# %%
df = pd.DataFrame(netflix_movies)
print (df)
# Out:
#                                       title  year  \
# 0                After Dark in Central Park  1900
# 1      Boarding School Girls' Pajama Parade  1900
# 2            Buffalo Bill's Wild West Parad  1900
# 3                                    Caught  1900
# 4                      Clowns Spinning Hats  1900
# ...                                     ...   ...
# 28790                             Bumblebee  2018
# 28791                     Welcome to Marwen  2018
# 28792                     Holmes and Watson  2018
# 28793                   On the Basis of Sex  2018
# 28794                             Destroyer  2018
#
#                                                     cast  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...

# %%
df['year'].mean()
# Out:
# 1959.9489841986456

# %%
df['year'].median()
# Out:
# 1952.0

# %%
df['year'].mode()
# Out:
# 0    1919
# dtype: int64

# %%
df['year'].sum()
# Out:
# 56436731

# %%
df['year'].value_counts()[2018]
# Out:
# 236

# %%
df['year'].value_counts()[1900]
# Out:
# 17
